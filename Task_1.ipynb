# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirrat21/Data-Science-Analytics_Internship_Tasks/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3da1920a-d166-4bfa-90ef-f3708e9480c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3da1920a-d166-4bfa-90ef-f3708e9480c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %% [markdown]
# # Shape (rows, columns)

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# # Column Names

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # First 5 Rows

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Basic Data Summary

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # **Visualizations**

# %% [markdown]
# # 1. Scatter Plot (Relationship between variables)

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df)
plt.title("Sepal Length vs Width")
plt.show()

# %% [markdown]
# # 2. Histogram (Data Distribution)

# %%
df['PetalLengthCm'].hist()
plt.title("Petal Length Distribution")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # 3. Box Plot (Outliers Detection)

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
plt.title("Sepal Length by Species")
plt.show()

# %% [markdown]
# # **CONCLUSION**
#
# 1. Loaded the Iris dataset using pandas in Google Colab.
# 2. Explored dataset structure using .shape, .columns, and .head().
# 3. Analyzed data using descriptive statistics with .describe().
# 4. Created a scatter plot to study relationships between variables.
# 5. Used a histogram to understand data distribution.
# 6. Applied a box plot to identify outliers and data spread.
# 7. Used matplotlib and seaborn for visualization.
# 8. Improved understanding of data analysis and visualization techniques.
